# %%
import pandas as pd
import requests
import time
import random
import string

df = pd.read_csv("xcl_map.csv")

names = df["display_name"].apply(lambda x: x.replace("_", " ")).tolist()

def get_wikidata_qid(name):
    query = f'''
    SELECT ?item WHERE {{
      # ?item rdfs:label "{name}"@en.
    }} LIMIT 1
    '''
    url = "https://query.wikidata.org/sparql"
    headers = {"Accept": "application/sparql-results+json"}
    try:
        response = requests.get(url, params={'query': query}, headers=headers, timeout=10)
        data = response.json()
        results = data["results"]["bindings"]
        if results:
            qid = results[0]["item"]["value"].split("/")[-1]
            return qid
    except Exception as e:
        print(f"Error fetching for '{name}':", e)

    # Fallback: generate a random ID
    return "RND" + ''.join(random.choices(string.digits, k=6))

# Fetch Q-IDs for all names
print("Fetching Q-IDs...")
qid_map = {}
for name in names:
    qid = get_wikidata_qid(name)
    qid_map[name] = qid
    print(f"{name} → {qid}")
    time.sleep(1)  # avoid rate limits

# Map back to DataFrame
df["wikidata_qid"] = df["display_name"].apply(lambda x: qid_map[x.replace("_", " ")])
# Out:
# Fetching Q-IDs...
# Abert's Towhee → Q3178867
# Mountain Chickadee → Q973320
# Northern Pintail → Q25450
# Northern Parula → Q27075910
# Northern Mockingbird → Q829683
# Northern Lapwing → Q25392
# Northern Hawk Owl → RND219479
# Northern Flicker → Q16819
# Northern Cardinal → Q726389
# Northern Bobwhite → Q142651
# New Zealand Bellbird → Q394708
# Nashville Warbler → Q27075894
# Mute Swan → Q25402
# Mourning Warbler → Q27075897
# Mourning Dove → Q11937719
# Morelet's Seedeater → Q31874551
# Greater Pewee → Q1263607
# Montezuma Oropendola → Q934975
# Montagu's Harrier → RND439261
# Monk Parakeet → Q724987
# Mistle Thrush → Q178942
# Middle Spotted Woodpecker → Q275591
# Mexican Jay → Q942604
# Mexican Duck → RND412182
# Merlin → Q76148
# Melodious Blackbird → Q1588405
# Meadow Pipit → Q26956
# Masked Tityra → Q1304903
# Marsh Wren → Q1379530
# Marsh Tit → Q207838
# Northern Shoveler → Q28106731
# Northern Waterthrush → Q27075884
# Northern Wheatear → Q26420
# Nuttall's Woodpecker → RND060692
# Prairie Warbler → Q27075937
# Plain Prinia → Q73928
# Plain Chachalaca → Q772929
# Pine Warbler → Q27075932
# Pine Siskin → Q26847063
# Pine Grosbeak → Q214571
# Pileated Woodpecker → Q930712
# Pied Kingfisher → Q320043
# Pied Crow → Q949603
# Pied Butcherbird → Q1301153
# Pied Avocet → RND662443
# Picazuro Pigeon → Q1269659
# Philadelphia Vireo → Q596275
# Phainopepla → Q10804973
# Peregrine Falcon → Q112200272
# Pectoral Sandpiper → Q260716
# Parasitic Jaeger → Q203053
# Palm Warbler → Q27075928
# Palm Tanager → Q1301273
# Painted Redstart → RND567937
# Painted Bunting → Q932970
# Pacific Wren → RND453657
# Ovenbird → Q796672
# Osprey → Q413017
# Orchard Oriole → Q1586976
# Olive Sparrow → Q2669759
# Oak Titmouse → Q2889018
# Marsh Sandpiper → Q28355
# Marbled Godwit → Q844714
# Mandarin Duck → Q200339
# Lapland Longspur → Q208703
# Kentish Plover → Q18855
# Italian Sparrow → Q937933
# Indigo Bunting → Q1049642
# Inca Dove → Q680708
# Hutton's Vireo → Q2667675
# House Sparrow → Q14683
# House Finch → RND438490
# House Crow → Q507383
# Horned Lark → Q207249
# Hooded Warbler → Q27075904
# Hooded Siskin → RND887064
# Hooded Oriole → Q1302812
# Hooded Crow → Q25405
# Hoatzin → Q188660
# Hermit Warbler → Q903940
# Hermit Thrush → Q846350
# Hepatic Tanager → RND756356
# Helmeted Guineafowl → Q251842
# Hawfinch → Q174088
# Hammond's Flycatcher → Q1261051
# Hairy Woodpecker → Q27074928
# Guira Cuckoo → Q911917
# Green Sandpiper → Q28450
# Green Kingfisher → RND874159
# Green Jay → Q15616389
# Green Heron → Q498228
# Greater Yellowlegs → Q570379
# Killdeer → Q755737
# Lark Sparrow → Q1528805
# Mallard → Q448635
# Laughing Dove → RND894681
# Magnolia Warbler → Q27075915
# MacGillivray's Warbler → Q27075896
# Louisiana Waterthrush → Q27075882
# Loggerhead Shrike → Q430863
# Little Tern → Q12267692
# Little Stint → Q27232
# Little Ringed Plover → Q18851
# Little Owl → Q129958
# Little Grebe → Q25421
# Little Egret → Q131709
# Lineated Woodpecker → Q1269603
# Lincoln's Sparrow → Q692323
# Limpkin → Q131107362
# Lesser Yellowlegs → Q28000
# Lesser Whitethroat → Q110257504
# Lesser Spotted Woodpecker → Q184518
# Lesser Nighthawk → Q1274529
# Lesser Goldfinch → Q27075863
# Least Tern → Q28168
# Least Sandpiper → Q913052
# Least Grebe → Q953976
# Least Flycatcher → Q944011
# Least Bittern → Q469586
# Lazuli Bunting → Q786964
# Lawrence's Goldfinch → RND574103
# Laughing Gull → Q528764
# Laughing Falcon → Q903642
# Prothonotary Warbler → Q206535
# Purple Finch → Q27075782
# Purple Heron → Q160488
# Warbling Vireo → Q596266
# Village Weaver → Q1070285
# Vesper Sparrow → Q776555
# Vermilion Flycatcher → Q41017122
# Verdin → Q1300274
# Veery → Q1047971
# Varied Bunting → Q934456
# Ural Owl → Q190083
# Upland Sandpiper → Q530194
# Tundra Swan → RND007773
# Tufted Titmouse → Q738534
# Tufted Duck → Q26444
# Tropical Parula → Q27075912
# Tropical Mockingbird → Q1591500
# Tropical Kingbird → RND990630
# Tricolored Blackbird → Q890921
# Tree Swallow → Q922192
# Tree Pipit → Q143313
# Townsend's Warbler → Q512543
# Townsend's Solitaire → Q2668264
# Tennessee Warbler → Q126925
# Tawny Owl → Q25756
# Swamp Sparrow → Q742826
# Swainson's Thrush → Q545006
# Summer Tanager → Q1078246
# Striated Heron → Q270722
# Streaked Flycatcher → Q875860
# Stock Dove → Q26140
# Virginia Rail → Q747837
# Wattled Jacana → RND128620
# Squirrel Cuckoo → Q1270495
# Western Bluebird → Q882923
# Zebra Dove → Q288485
# Yellowhammer → Q26205
# Yellow Warbler → Q20185745
# Wrentit → Q1048896
# Woodchat Shrike → Q235052
# Wood Thrush → Q65082498
# Wood Sandpiper → Q18837
# Wood Duck → Q322159
# Winter Wren → Q10828228
# Wilson's Warbler → Q27076007
# Wilson's Snipe → Q64927
# Wilson's Plover → Q979488
# Willow Warbler → Q27239
# Willow Tit → Q215211
# Willow Flycatcher → Q903847
# Willet → Q831611
# Wild Turkey → Q26844
# Whooper Swan → Q25612
# White Wagtail → Q25399
# Whiskered Tern → Q233616
# Whinchat → Q155869
# Whimbrel → Q83652326
# Western Yellow Wagtail → Q25984
# Western Tanager → Q384342
# Western Meadowlark → Q1368136
# Western Kingbird → Q673149
# Western Grebe → Q679154
# Steller's Jay → Q838749
# Spotted Towhee → RND520314
# Purple Martin → Q1062485
# Sandwich Tern → Q27547
# Sanderling → Q58958
# Sage Thrasher → Q1587710
# Saffron Finch → Q1064372
# Rusty Blackbird → Q1314688
# Rufous Whistler → Q3180293
# Rufous Hummingbird → Q1190038
# Rufous Hornero → Q852731
# Ruddy Turnstone → Q26892
# Ruddy Shelduck → Q170723
# Royal Tern → Q28423
# Rook → Q25386
# Rock Wren → Q935880
# Rock Pigeon → RND877736
# Roadside Hawk → Q426708
# Rivoli's Hummingbird → RND856132
# Ringed Kingfisher → Q1272848
# Reed Bunting → Q26961
# Redwing → Q184825
# Red Phalarope → Q208335
# Red Knot → Q27124
# Red Kite → Q156250
# Red Junglefowl → RND425372
# Red Crossbill → Q26552
# Razorbill → Q27102
# Pyrrhuloxia → RND974199
# Pygmy Nuthatch → RND050200
# Purple Sunbird → Q1797393
# Sandhill Crane → RND212237
# Sardinian Warbler → RND507645
# Spotted Sandpiper → Q389691
# Savannah Sparrow → Q287893
# Spotted Redshank → Q28103
# Spotted Flycatcher → Q26607
# Spotted Dove → RND446186
# Spotless Starling → Q836833
# Sparkling Violetear → Q929489
# Southern Lapwing → Q855348
# Sora → Q13284
# Song Thrush → Q26349
# Song Sparrow → Q842599
# Solitary Sandpiper → Q836304
# Social Flycatcher → Q1265429
# Snow Goose → Q65083624
# Snow Bunting → Q26416
# Snail Kite → Q839657
# Silvereye → Q313394
# Shiny Cowbird → Q1586890
# Shikra → Q715710
# Semipalmated Sandpiper → Q735092
# Semipalmated Plover → Q468009
# Sedge Wren → RND292682
# Sedge Warbler → Q27236
# Scott's Oriole → Q1305283
# Scarlet Tanager → Q1193366
# Scarlet Macaw → Q243761
# Scaled Quail → Q786840
# Sayaca Tanager → Q1588073
# Say's Phoebe → RND333741
# Greater Roadrunner → Q634804
# Horned Grebe → Q192058
# Greater Flamingo → Q179863
# Clapper Rail → Q15881126
# Cirl Bunting → Q148583
# Chukar → Q16769157
# Chipping Sparrow → Q645203
# Cedar Waxwing → Q184314
# Cattle Tyrant → Q656000
# Cassin's Vireo → Q1588260
# Cassin's Kingbird → Q1261628
# Cassin's Finch → RND047393
# Caspian Tern → Q27129
# Carrion Crow → Q26198
# Carolina Wren → Q1585636
# Carolina Chickadee → Q1079441
# Cape May Warbler → Q27075908
# Canyon Wren → Q776497
# Canyon Towhee → Q3180746
# Canada Warbler → Q27076004
# Canada Goose → Q26733
# Campo Flicker → Q1274176
# California Towhee → Q3178443
# California Thrasher → Q2225831
# California Quail → Q830385
# Cactus Wren → Q969006
# Bushtit → RND954303
# Burrowing Owl → Q467068
# Bullock's Oriole → Q851912
# Brown Thrasher → Q928134
# Brown Shrike → Q790616
# Citrine Wagtail → Q206540
# Clark's Nutcracker → Q1142785
# Common Snipe → Q25692
# Cliff Swallow → RND636108
# Common Sandpiper → Q18850
# Common Rosefinch → Q46143
# Common Ringed Plover → Q26816
# Common Redstart → Q26620
# Common Redshank → Q18859
# Common Raven → RND146610
# Common Pochard → Q26742
# Common Pauraque → RND189676
# Common Nighthawk → Q943329
# Common Murre → Q21062
# Common Merganser → Q180991
# Common Loon → RND605186
# Common Kingfisher → Q79915
# Common Greenshank → Q18840
# Common Grackle → Q1424486
# Common Goldeneye → Q29865
# Common Gallinule → Q1263469
# Common Firecrest → Q27471
# Greater Coucal → Q767112
# Common Cuckoo → Q18845
# Common Crane → Q4764
# Common Chiffchaff → Q185784
# Common Buzzard → Q25385
# Common Bulbul → Q790596
# Collared Trogon → Q1034953
# Collared Kingfisher → Q31898
# Coal Tit → Q191096
# Brown Jay → Q28872863
# Brown Creeper → Q490294
# Bronzed Cowbird → Q1190592
# Bridled Titmouse → Q2888535
# Barred Antshrike → Q863581
# Barnacle Goose → Q26680
# Barn Swallow → Q25429
# Bank Swallow → RND650135
# Bananaquit → Q228125
# Baltimore Oriole → Q805774
# Bald Eagle → Q127216
# Baird's Sandpiper → Q788649
# Australasian Figbird → RND862659
# Asian Koel → RND413167
# Arctic Tern → Q26800
# Anna's Hummingbird → Q564265
# American Woodcock → Q694319
# American Tree Sparrow → Q27076037
# American Robin → Q460967
# American Redstart → Q922772
# American Pipit → RND191929
# American Oystercatcher → Q692644
# American Kestrel → Q651545
# American Goldfinch → Q27075861
# American Crow → Q267735
# American Coot → Q470016
# American Bittern → Q743017
# Amazon Kingfisher → Q456421
# Altamira Oriole → Q1300686
# African Pied Wagtail → Q530069
# Acorn Woodpecker → RND396315
# Barred Owl → Q630457
# Bat Falcon → Q844220
# Bell's Vireo → Q1303897
# Blue Grosbeak → Q794337
# Brewer's Sparrow → Q659632
# Brewer's Blackbird → Q339139
# Brant → Q404012
# Brambling → Q188877
# Boreal Chickadee → Q385343
# Bonaparte's Gull → Q629525
# Bohemian Waxwing → Q26135
# Bobolink → Q591831
# Blyth's Reed Warbler → RND875843
# Bluethroat → Q26578
# Blue Mockingbird → Q1587047
# Blue Jay → Q127241
# Blacksmith Lapwing → Q931114
# Belted Kingfisher → Q736052
# Blackpoll Warbler → Q27075924
# Blackburnian Warbler → Q27075919
# Black Woodpecker → Q143284
# Black Tern → Q27215
# Black Skimmer → Q516662
# Black Redstart → Q26755
# Black Phoebe → Q920950
# Black Kite → Q80362
# Black Drongo → Q46435
# Black Bulbul → RND201395
# Bewick's Wren → Q997457
# Berylline Hummingbird → Q793835
# Common Shelduck → Q25761
# Common Eider → Q26696
# Common Swift → Q25377
# Eurasian Wren → Q25740
# Fieldfare → Q25777
# Field Sparrow → Q611926
# Evening Grosbeak → Q25167830
# European Stonechat → Q838665
# European Starling → RND706066
# European Serin → Q271807
# European Roller → Q179367
# European Robin → Q25334
# European Pied Flycatcher → RND513298
# Common Tailorbird → Q795556
# European Greenfinch → Q27075785
# Eurasian Wryneck → Q25678
# Eurasian Wigeon → Q20780398
# Elegant Trogon → Q632823
# Eurasian Tree Sparrow → Q25968
# Eurasian Sparrowhawk → Q25380
# Eurasian Siskin → Q27075864
# Eurasian Nuthatch → Q156767
# Eurasian Magpie → RND309759
# Eurasian Jay → Q25354
# Eurasian Jackdaw → Q25394
# Eurasian Hobby → Q25876
# Eurasian Golden Oriole → Q25388
# Eurasian Curlew → RND336996
# Eurasian Coot → RND210416
# Eurasian Bullfinch → Q25382
# Fish Crow → Q1420315
# Forster's Tern → Q430529
# Fox Sparrow → RND413502
# Gadwall → Q5516474
# Great Tit → Q25485
# Great Thrush → Q1067396
# Great Spotted Woodpecker → Q26209
# Great Kiskadee → Q202804
# Great Horned Owl → Q81515
# Great Gray Owl → RND003708
# Great Egret → Q130730
# Great Crested Grebe → Q25422
# Great Crested Flycatcher → Q1052057
# Great Cormorant → Q25440
# Great Blue Heron → Q333796
# Grayish Baywing → RND053174
# Gray Shrikethrush → RND261533
# Gray Partridge → RND720987
# Gray Kingbird → Q945200
# Gray Hawk → Q5598183
# Gray Catbird → Q831597
# Grasshopper Sparrow → Q1588210
# Golden Eagle → Q41181
# Goldcrest → Q26657
# Glossy Ibis → Q65083657
# Gila Woodpecker → Q557493
# Gartered Trogon → Q1262495
# Garganey → Q28106902
# Gambel's Quail → Q1007906
# Eurasian Blackbird → RND074745
# Zitting Cisticola → Q210791
# Daurian Redstart → Q616456
# Crested Caracara → RND396303
# Dickcissel → Q1210224
# Dunlin → Q26650
# Dunnock → Q26698
# Curlew Sandpiper → Q62345
# Crested Tit → RND936772
# Eared Grebe → Q65083738
# Eastern Bluebird → Q600880
# Crested Myna → Q715819
# Eastern Kingbird → RND049831
# Crested Lark → Q26982
# Crested Guan → RND222471
# Downy Woodpecker → Q27074911
# Eastern Phoebe → RND195150
# Eastern Meadowlark → Q1589550
# Couch's Kingbird → Q1260307
# Cooper's Hawk → Q862896
# Common Tern → Q18875
# Elegant Tern → Q524893
# Eastern Towhee → Q1541137
# Common Waxbill → Q583220
# Common Yellowthroat → Q281555
# Dollarbird → RND349713
# Corn Bunting → Q27220
# Egyptian Goose → Q274179
# Mediterranean Gull → Q276189
# Rock Bunting → Q205491
# Toco Toucan → Q376038
# Lesser Violetear → RND902935
# Ridgway's Rail → RND115688
# Water Pipit → Q208707
# Southern Screamer → Q602961
# Elegant Euphonia → RND616096
# Kentucky Warbler → Q27075899
# Woodland Kingfisher → Q838793
# Brown Thornbill → Q264390
# Plumbeous Vireo → Q1318023
# Caspian Gull → Q389505
# Eastern Yellow Wagtail → Q4810698
# Malachite Sunbird → Q1300638
# Masked Gnatcatcher → Q902015
# Tufted Flycatcher → RND581694
# Little Gull → Q164467
# Blue Dacnis → RND505757
# Common Poorwill → Q930457
# Gray Flycatcher → RND435838
# Spanish Sparrow → Q466200
# Spangled Drongo → Q1002070
# Gray Treepie → RND413979
# Common Iora → Q26537
# Acadian Flycatcher → Q252175
# Chiguanco Thrush → RND438379
# Black Crake → Q28106640
# Crested Oropendola → Q906518
# Crested Barbet → Q1264584
# Asian Brown Flycatcher → Q27075642
# Yellow Grosbeak → Q648197
# Pied Bushchat → RND019726
# Coppersmith Barbet → Q27074872
# Thrush Nightingale → Q206130
# Cassin's Sparrow → Q2229803
# Rock Pipit → RND120240
# Fiscal Flycatcher → Q785807
# Little Bittern → Q26129
# Alpine Accentor → Q208334
# Collared Sunbird → Q839914
# Greater Ani → Q730129
# Booted Warbler → Q757116
# Cerulean Warbler → Q25066647
# Austral Thrush → Q1590629
# Common Potoo → Q1258935
# Mottled Owl → Q185279
# Temminck's Stint → RND338837
# Crane Hawk → Q744953
# Terek Sandpiper → Q18856
# Rufous Treepie → Q282256
# Bell's Sparrow → Q792447
# Olive Warbler → Q260726
# Southern Boubou → Q1304963
# Jungle Babbler → Q62098182
# Ashy Drongo → Q283608
# Wood Warbler → Q27075477
# Lesser Kestrel → Q229408
# Common Chlorospingus → RND670784
# Alder Flycatcher → Q681933
# LeConte's Sparrow → Q28812551
# Oriental Greenfinch → RND166004
# Tawny Pipit → Q27226
# Garden Warbler → Q202478
# Collared Pratincole → Q330310
# Azure Tit → Q499283
# Arctic Loon → RND519599
# Rustic Bunting → Q286809
# Bokmakierie → Q891225
# Ortolan Bunting → Q206630
# Swallow Tanager → RND120841
# Mitred Parakeet → RND371919
# Hazel Grouse → Q182761
# Scarlet Minivet → Q12265751
# Water Rail → Q185099
# Henslow's Sparrow → Q1588203
# Eurasian Bittern → Q25709
# Grace's Warbler → Q27075938
# Lucy's Warbler → Q27075892
# Syrian Woodpecker → Q752481
# Sombre Greenbul → Q941386
# Crimson Sunbird → RND282805
# Bearded Reedling → RND550722
# Juniper Titmouse → Q2224815
# Golden Tanager → Q776016
# Green Ibis → Q912057
# Variable Oriole → Q5419907
# Demoiselle Crane → Q23759614

# %%
df
# Out:
#      index        mid          display_name wikidata_qid
# 0        1   Q3178867        Abert's_Towhee     Q3178867
# 1        2    Q973320    Mountain_Chickadee      Q973320
# 2        3     Q25450      Northern_Pintail       Q25450
# 3        4  Q27075910       Northern_Parula    Q27075910
# 4        5    Q829683  Northern_Mockingbird      Q829683
# ..     ...        ...                   ...          ...
# 540    541   Q2224815      Juniper_Titmouse     Q2224815
# 541    542    Q776016        Golden_Tanager      Q776016
# 542    543    Q912057            Green_Ibis      Q912057
# 543    544   Q5419907       Variable_Oriole     Q5419907
# 544    545  Q23759614      Demoiselle_Crane    Q23759614
#
# [545 rows x 4 columns]

# %%
df['mid'] = df['wikidata_qid']

# %%
df.drop('wikidata_qid', axis=1, inplace=True)

# %%
df
# Out:
#      index        mid            display_name
# 0        1   Q3178867        "Abert's_Towhee"
# 1        2    Q973320    "Mountain_Chickadee"
# 2        3     Q25450      "Northern_Pintail"
# 3        4  Q27075910       "Northern_Parula"
# 4        5    Q829683  "Northern_Mockingbird"
# ..     ...        ...                     ...
# 540    541   Q2224815      "Juniper_Titmouse"
# 541    542    Q776016        "Golden_Tanager"
# 542    543    Q912057            "Green_Ibis"
# 543    544   Q5419907       "Variable_Oriole"
# 544    545  Q23759614      "Demoiselle_Crane"
#
# [545 rows x 3 columns]

# %%
df['display_name'] = df['display_name'].apply(lambda x: "\""+x+"\"")

# %%
import csv
df.to_csv("xcl_map_with_qids.csv", sep=',', index=False, encoding='utf-8', quoting=csv.QUOTE_NONE)
